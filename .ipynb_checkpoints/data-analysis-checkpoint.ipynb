# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/popular_10000_movies_tmdb.csv")

# %%
df.head()
# Out:
#        id                              title release_date  \
# 0  758323                The Pope's Exorcist   2023-04-05
# 1  640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2  502356        The Super Mario Bros. Movie   2023-04-05
# 3  868759                            Ghosted   2023-04-18
# 4  594767           Shazam! Fury of the Gods   2023-03-15
#
#                                               genres original_language  \
# 0                  ['Horror', 'Mystery', 'Thriller']           English
# 1         ['Action', 'Adventure', 'Science Fiction']           English
# 2  ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                    ['Action', 'Comedy', 'Romance']           English
# 4       ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
#
#    vote_average  vote_count  popularity  \
# 0           7.4         619    5089.969
# 1           6.6        2294    4665.438
# 2           7.5        1861    3935.550
# 3           7.2         652    2791.532
# 4           6.8        1510    2702.593
#
#                                             overview     budget  \
# 0  Father Gabriele Amorth, Chief Exorcist of the ...   18000000
# 1  Super-Hero partners Scott Lang and Hope van Dy...  200000000
# 2  While working underground to fix a water main,...  100000000
# 3  Salt-of-the-earth Cole falls head over heels f...          0
# 4  Billy Batson and his foster siblings, who tran...  125000000
#
#                                 production_companies     revenue  runtime  \
# 0  ['Screen Gems', '2.0 Entertainment', 'Jesus & ...    65675816      103
# 1      ['Marvel Studios', 'Kevin Feige Productions']   464566092      125
# 2  ['Universal Pictures', 'Illumination', 'Ninten...  1121048165       92
# 3                ['Skydance Media', 'Apple Studios']           0      120
# 4  ['New Line Cinema', 'The Safran Company', 'DC ...   133437105      130
#
#                                              tagline
# 0  Inspired by the actual files of Father Gabriel...
# 1            Witness the beginning of a new dynasty.
# 2                                                NaN
# 3  Finding that special someone can be a real adv...
# 4                                      Oh. My. Gods.

# %%
#veri seti hakkında genel  bilgi alalım.
def check_df(dataframe,head = 5):
    print(" Shape ".center(60, '#'))
    print('Observations -------> {}'.format(df.shape[0]))
    print('Features     -------> {}'.format(df.shape[1]))
    print(" Types ".center(60, '#'))
    print(dataframe.dtypes)
    print(" İnfo ".center(60, '#'))
    print(dataframe.info())
    print(" Head ".center(60, '#'))
    print(dataframe.head(head))
    print(" Tail ".center(60, '#'))
    print(dataframe.tail(head))
    print(" NA ".center(60, '#'))
    print(dataframe.isnull().sum())
    print(" Columns ".center(60,'#'))
    print(df.columns)
    
check_df(df)
# Out:
# ########################## Shape ###########################
# Observations -------> 10000
# Features     -------> 14
# ########################## Types ###########################
# id                        int64
# title                    object
# release_date             object
# genres                   object
# original_language        object
# vote_average            float64
# vote_count                int64
# popularity              float64
# overview                 object
# budget                    int64
# production_companies     object
# revenue                   int64
# runtime                   int64
# tagline                  object
# dtype: object
# ########################### İnfo ###########################
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10000 non-null  int64
#  1   title                 10000 non-null  object
#  2   release_date          9979 non-null   object
#  3   genres                10000 non-null  object
#  4   original_language     10000 non-null  object
#  5   vote_average          10000 non-null  float64
#  6   vote_count            10000 non-null  int64
#  7   popularity            10000 non-null  float64
#  8   overview              9923 non-null   object
#  9   budget                10000 non-null  int64
#  10  production_companies  10000 non-null  object
#  11  revenue               10000 non-null  int64
#  12  runtime               10000 non-null  int64
#  13  tagline               7241 non-null   object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.1+ MB
# None
# ########################### Head ###########################
#        id                              title release_date  \
# 0  758323                The Pope's Exorcist   2023-04-05
# 1  640146  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2  502356        The Super Mario Bros. Movie   2023-04-05
# 3  868759                            Ghosted   2023-04-18
# 4  594767           Shazam! Fury of the Gods   2023-03-15
#
#                                               genres original_language  \
# 0                  ['Horror', 'Mystery', 'Thriller']           English
# 1         ['Action', 'Adventure', 'Science Fiction']           English
# 2  ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                    ['Action', 'Comedy', 'Romance']           English
# 4       ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
#
#    vote_average  vote_count  popularity  \
# 0           7.4         619    5089.969
# 1           6.6        2294    4665.438
# 2           7.5        1861    3935.550
# 3           7.2         652    2791.532
# 4           6.8        1510    2702.593
#
#                                             overview     budget  \
# 0  Father Gabriele Amorth, Chief Exorcist of the ...   18000000
# 1  Super-Hero partners Scott Lang and Hope van Dy...  200000000
# 2  While working underground to fix a water main,...  100000000
# 3  Salt-of-the-earth Cole falls head over heels f...          0
# 4  Billy Batson and his foster siblings, who tran...  125000000
#
#                                 production_companies     revenue  runtime  \
# 0  ['Screen Gems', '2.0 Entertainment', 'Jesus & ...    65675816      103
# 1      ['Marvel Studios', 'Kevin Feige Productions']   464566092      125
# 2  ['Universal Pictures', 'Illumination', 'Ninten...  1121048165       92
# 3                ['Skydance Media', 'Apple Studios']           0      120
# 4  ['New Line Cinema', 'The Safran Company', 'DC ...   133437105      130
#
#                                              tagline
# 0  Inspired by the actual files of Father Gabriel...
# 1            Witness the beginning of a new dynasty.
# 2                                                NaN
# 3  Finding that special someone can be a real adv...
# 4                                      Oh. My. Gods.
# ########################### Tail ###########################
#           id                              title release_date  \
# 9995  374473                    I, Daniel Blake   2016-10-21
# 9996   16774  Hellboy Animated: Sword of Storms   2006-10-28
# 9997   13564    Return to House on Haunted Hill   2007-10-03
# 9998  482204             My Sister-in-law's Job   2017-08-31
# 9999  444539                       The Bookshop   2017-11-10
#
#                                                  genres original_language  \
# 9995                                          ['Drama']           English
# 9996  ['TV Movie', 'Fantasy', 'Animation', 'Action',...           English
# 9997                             ['Horror', 'Thriller']           English
# 9998                               ['Drama', 'Romance']            Korean
# 9999                                          ['Drama']           English
#
#       vote_average  vote_count  popularity  \
# 9995           7.7        1220      10.774
# 9996           6.3          99      12.739
# 9997           5.6         263      12.769
# 9998           5.0           5      10.425
# 9999           6.5         382      12.525
#
#                                                overview   budget  \
# 9995  A middle aged carpenter, who requires state we...        0
# 9996  A folklore professor becomes unwittingly posse...        0
# 9997  Eight years have passed since Sara Wolfe and E...        0
# 9998  An erotic film that depicts the dangerous rela...        0
# 9999  Set in a small English town in 1959, a woman d...  5400000
#
#                                    production_companies   revenue  runtime  \
# 9995  ['Why Not Productions', 'Wild Bunch', 'Sixteen...  15793051      100
# 9996                ['IDT Entertainment', 'Film Roman']         0       73
# 9997   ['Dark Castle Entertainment', 'Warner Premiere']         0       81
# 9998                                                 []         0       89
# 9999  ['Zephyr Films', 'A Contracorriente Films', 'D...  12055868      110
#
#                                                 tagline
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999  A town that lacks a bookshop isn't always a to...
# ############################ NA ############################
# id                         0
# title                      0
# release_date              21
# genres                     0
# original_language          0
# vote_average               0
# vote_count                 0
# popularity                 0
# overview                  77
# budget                     0
# production_companies       0
# revenue                    0
# runtime                    0
# tagline                 2759
# dtype: int64
# ######################### Columns ##########################
# Index(['id', 'title', 'release_date', 'genres', 'original_language',
#        'vote_average', 'vote_count', 'popularity', 'overview', 'budget',
#        'production_companies', 'revenue', 'runtime', 'tagline'],
#       dtype='object')

# %%
df['overview'][0]
# Out:
# "Father Gabriele Amorth, Chief Exorcist of the Vatican, investigates a young boy's terrifying possession and ends up uncovering a centuries-old conspiracy the Vatican has desperately tried to keep hidden."

# %%
df['tagline'][0]
# Out:
# 'Inspired by the actual files of Father Gabriele Amorth, Chief Exorcist of the Vatican.'

# %%
df.drop(['id','overview','tagline'], axis=1,inplace = True)

# %%
df.columns
# Out:
# Index(['title', 'release_date', 'genres', 'original_language', 'vote_average',
#        'vote_count', 'popularity', 'budget', 'production_companies', 'revenue',
#        'runtime'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# title                    0
# release_date            21
# genres                   0
# original_language        0
# vote_average             0
# vote_count               0
# popularity               0
# budget                   0
# production_companies     0
# revenue                  0
# runtime                  0
# dtype: int64

# %%
df.dropna(axis =0, inplace = True)

# %%
df.columns
# Out:
# Index(['title', 'release_date', 'genres', 'original_language', 'vote_average',
#        'vote_count', 'popularity', 'budget', 'production_companies', 'revenue',
#        'runtime'],
#       dtype='object')

# %%
df.shape
# Out:
# (9979, 11)

# %%
df['original_language'].unique()
# Out:
# array(['English', 'French', 'Dutch', 'Spanish', 'Korean', 'Japanese',
#        'Finnish', 'Ukrainian', 'Norwegian', 'Estonian', 'cn', 'Polish',
#        'Russian', 'German', 'Chinese', 'Italian', 'Basque', 'Thai',
#        'Turkish', 'Swedish', 'Icelandic', 'Tagalog', 'Bengali', 'Arabic',
#        'Tamil', 'Telugu', 'Romanian', 'Indonesian', 'Galician', 'Danish',
#        'Macedonian', 'Portuguese', 'Vietnamese', 'Catalan', 'Hindi',
#        'Persian', 'Hebrew', 'Serbian', 'Malayalam', 'Greek', 'Hungarian',
#        'Czech', 'Norwegian Bokmal', 'xx', 'Kannada', 'Irish', 'Khmer',
#        'sh', 'Dzongkha', 'Panjabi', 'Sundanese'], dtype=object)

# %%
df[df['original_language'] == "xx"]
# Out:
#         title release_date     genres original_language  vote_average  \
# 6340   Barbie   1977-01-01         []                xx           2.0
# 7837  Vertigo   2016-08-10  ['Drama']                xx           2.0
#
#       vote_count  popularity  budget production_companies  revenue  runtime
# 6340           1       9.890       0                   []        0       10
# 7837           1      10.093     200                   []        0        6

# %%
df = df[~(df['original_language'] == 'xx')]

# %%
df.shape
# Out:
# (9977, 11)

# %%
df[df['original_language'] == "sh"]
# Out:
#                    title release_date               genres original_language  \
# 9096  I Miss Sonia Henie   1971-01-20  ['Comedy', 'Drama']                sh
#
#       vote_average  vote_count  popularity  budget production_companies  \
# 9096           5.5          15      13.323       0   ['Neoplanta Film']
#
#       revenue  runtime
# 9096        0       16

# %%
df = df[~(df['original_language'] == 'sh')]

# %%
df.shape
# Out:
# (9976, 11)

# %%
#DataFrame'deki tekrar eden  girişlerin sayısı

df.duplicated().sum()
# Out:
# 0

# %%
df['title'].nunique()
# Out:
# 9629

# %%
df["title"].duplicated().sum()
# Out:
# 347

# %%
df[df['title'].isin(df['title'][df['title'].duplicated()])].sort_values('title')
# Out:
#                           title release_date  \
# 9364               3:10 to Yuma   1957-08-07
# 5116               3:10 to Yuma   2007-09-06
# 2684  A Nightmare on Elm Street   2010-04-30
# 1637  A Nightmare on Elm Street   1984-11-09
# 7330      A Tale of Two Sisters   2023-05-06
# ...                         ...          ...
# 902                Wonder Woman   2017-05-30
# 1133                 Wrong Turn   2003-05-30
# 774                  Wrong Turn   2021-01-26
# 202                           X   2022-03-17
# 5515                          X   2011-11-23
#
#                                   genres original_language  vote_average  \
# 9364    ['Western', 'Drama', 'Thriller']           English           7.2
# 5116                         ['Western']           English           7.2
# 2684   ['Horror', 'Mystery', 'Thriller']           English           5.5
# 1637                          ['Horror']           English           7.3
# 7330                                  []           English           0.0
# ...                                  ...               ...           ...
# 902   ['Action', 'Adventure', 'Fantasy']           English           7.2
# 1133              ['Horror', 'Thriller']           English           6.3
# 774      ['Horror', 'Thriller', 'Drama']           English           6.0
# 202    ['Horror', 'Mystery', 'Thriller']           English           6.8
# 5515   ['Action', 'Thriller', 'Romance']           English           6.5
#
#       vote_count  popularity     budget  \
# 9364         291      10.993          0
# 5116        3131      18.967   55000000
# 2684        2415      25.679   35000000
# 1637        4430      36.600    1100000
# 7330           0      10.538          0
# ...          ...         ...        ...
# 902        18595      54.481  149000000
# 1133        2307      50.411   12600000
# 774          902      59.587          0
# 202         1918     129.629   10000000
# 5515         221      20.592          0
#
#                                    production_companies    revenue  runtime
# 9364                              ['Columbia Pictures']          0       92
# 5116  ['Lionsgate', 'Tree Line Films', 'Relativity M...   70016220      122
# 2684  ['Platinum Dunes', 'New Line Cinema', 'Warner ...  115664037       95
# 1637  ['New Line Cinema', 'Smart Egg Pictures', 'Med...   57000000       91
# 7330                                                 []          0        8
# ...                                                 ...        ...      ...
# 902   ['Atlas Entertainment', 'Cruel & Unusual Films...  822854286      141
# 1133  ['DCP Wrong Turn Productions', 'Summit Enterta...   28650575       84
# 774   ['Constantin Film', 'The H Collective', 'Tea S...    3777969      110
# 202                  ['A24', 'Little Lamb Productions']   14779858      106
# 5515                     ['Rough Beast', 'Circe Films']          0       90
#
# [661 rows x 11 columns]

# %%
df[df["genres"].str.len () ==2 ]
# Out:
#                                                  title release_date genres  \
# 610                                       Snake Beauty   1994-03-26     []
# 684                    Za gyakutai: Nyotai ikedori-hen   1987-07-18     []
# 816                         Gabriel's Inferno: Part IV   2022-03-30     []
# 943                                       Yu Pui Tsuen   1986-12-12     []
# 1178                                Oppressive Torture   1978-01-14     []
# ...                                                ...          ...    ...
# 8809                            The Legend of Zhao Yun   2021-01-04     []
# 8982                       Russian Nymphet: Temptation   2004-11-28     []
# 9484                     La Boheme: Breathe Umphefumlo   2015-02-05     []
# 9775                                               野浪花   1987-05-26     []
# 9991  The Witcher Season One Recap: From the Beginning   2021-12-17     []
#
#      original_language  vote_average  vote_count  popularity  budget  \
# 610            Chinese           0.0           0      61.292       0
# 684           Japanese           6.5           1      62.096       0
# 816            English           5.0           2      37.269       0
# 943                 cn           4.0           4      78.229       0
# 1178          Japanese           4.7           3      45.046       0
# ...                ...           ...         ...         ...     ...
# 8809           Chinese           2.0           1       9.461       0
# 8982           Russian           5.3           3      16.728       0
# 9484           English           6.7           3      11.171       0
# 9775           Chinese           0.0           0       8.040       0
# 9991           English           5.6           8       9.045       0
#
#                   production_companies  revenue  runtime
# 610   ['Ka Shing Film Production Co.']        0       88
# 684                      ['Orient 21']        0       64
# 816                                 []        0        0
# 943                                 []        0       93
# 1178          ['Wakamatsu Production']        0       61
# ...                                ...      ...      ...
# 8809                                []        0       96
# 8982                     ['Eros Film']        0       35
# 9484                                []        0        0
# 9775                                []        0        0
# 9991                                []        0       15
#
# [61 rows x 11 columns]

# %%
df = df[~(df['genres'].str.len() == 2)]

# %%
df.shape
# Out:
# (9915, 11)

# %%
df[df['production_companies'].str.len () ==2 ]
# Out:
#                                       title release_date  \
# 21                               Adrenaline   2022-12-15
# 27                              The Elderly   2023-04-21
# 28                         Ripper's Revenge   2023-04-03
# 36                           Gangs of Lagos   2023-04-07
# 46    Prizefighter: The Life of Jem Belcher   2022-06-30
# ...                                     ...          ...
# 9905                     My Mother's Lovers   2020-05-29
# 9924                    My Brother's Wife 2   2016-08-31
# 9930                      Zombie Fight Club   2014-10-23
# 9975                             Heart Shot   2022-02-17
# 9998                 My Sister-in-law's Job   2017-08-31
#
#                                  genres original_language  vote_average  \
# 21                           ['Action']           English           5.9
# 27    ['Horror', 'Thriller', 'Fantasy']           Spanish           5.8
# 28                           ['Horror']           English           4.9
# 36                            ['Crime']           English           6.1
# 46                 ['Drama', 'History']           English           6.2
# ...                                 ...               ...           ...
# 9905                          ['Drama']           Spanish           2.8
# 9924     ['Romance', 'Family', 'Drama']            Korean           3.5
# 9930               ['Action', 'Horror']           Chinese           4.7
# 9975               ['Romance', 'Crime']           English           5.6
# 9998               ['Drama', 'Romance']            Korean           5.0
#
#       vote_count  popularity     budget production_companies  revenue  runtime
# 21            39     717.878          0                   []        0       75
# 27             6     521.201          0                   []        0       95
# 28            10     523.118          0                   []        0       85
# 36            35     462.815  160000000                   []        0      124
# 46           122     365.065          0                   []        0      107
# ...          ...         ...        ...                  ...      ...      ...
# 9905           5      12.444          0                   []        0       22
# 9924           2      10.341          0                   []        0       98
# 9930          54      12.899          0                   []        0       95
# 9975          69       9.132          0                   []        0       19
# 9998           5      10.425          0                   []        0       89
#
# [519 rows x 11 columns]

# %%
df = df[~(df['production_companies'].str.len() == 2)]

# %%
(df ==0).sum()
# Out:
# title                      0
# release_date               0
# genres                     0
# original_language          0
# vote_average             130
# vote_count               129
# popularity                 0
# budget                  4286
# production_companies       0
# revenue                 3986
# runtime                  106
# dtype: int64

# %%
df[(df["vote_average"] ==0 ) | (df['vote_count'] == 0) | (df['runtime'] == 0)]
# Out:
#                                  title release_date  \
# 23                              Fast X   2023-05-17
# 100                        Kiss, Kiss!   2023-04-26
# 101                 The Little Mermaid   2023-05-18
# 128   Transformers: Rise of the Beasts   2023-06-07
# 184                          The Flash   2023-06-14
# ...                                ...          ...
# 9847      Divaldo: O Mensageiro da Paz   2019-09-12
# 9889                        Influencer   2023-05-18
# 9922                     Mental Finger   2023-05-06
# 9926        Patricia, A Hidden Passion   2020-01-21
# 9932   Godzilla x Kong: The New Empire   2024-03-13
#
#                                              genres original_language  \
# 23                  ['Action', 'Crime', 'Thriller']           English
# 100                           ['Romance', 'Comedy']            Polish
# 101   ['Adventure', 'Family', 'Fantasy', 'Romance']           English
# 128      ['Action', 'Adventure', 'Science Fiction']           English
# 184      ['Science Fiction', 'Action', 'Adventure']           English
# ...                                             ...               ...
# 9847                                      ['Drama']        Portuguese
# 9889              ['Thriller', 'Horror', 'Mystery']           English
# 9922                           ['Comedy', 'Action']         Sundanese
# 9926                            ['Drama', 'Comedy']           Spanish
# 9932     ['Action', 'Science Fiction', 'Adventure']           English
#
#       vote_average  vote_count  popularity     budget  \
# 23             0.0           0     732.647  340000000
# 100            6.9          15     361.900          0
# 101            0.0           0     220.944          0
# 128            0.0           0     222.430  200000000
# 184            0.0           0     123.659  220000000
# ...            ...         ...         ...        ...
# 9847           8.3          59      16.640          0
# 9889           0.0           0       8.454          0
# 9922           0.0           0       9.660          0
# 9926           6.0          33      12.780          0
# 9932           0.0           0      11.839          0
#
#                                    production_companies  revenue  runtime
# 23    ['Universal Pictures', 'Original Film', 'One R...        0      142
# 100                                      ['Lightcraft']        0        0
# 101   ['Walt Disney Pictures', 'Lucamar Productions'...        0      135
# 128   ['Skydance Media', 'Paramount', 'di Bonaventur...        0        0
# 184   ['Warner Bros. Pictures', 'Double Dream', 'The...        0        0
# ...                                                 ...      ...      ...
# 9847  ['20th Century Fox Brazil', 'CINE Cinematográf...        0        0
# 9889             ['Octane Entertainment', 'Superchill']        0       92
# 9922                              ['Cinemora Pictures']        0       12
# 9926                                    ['Cine Latino']        0        0
# 9932                             ['Legendary Pictures']        0        0
#
# [173 rows x 11 columns]

# %%
df = df[~((df['vote_average'] == 0) | (df['vote_count'] == 0) | (df['runtime'] == 0))]

# %%
df.shape
# Out:
# (9223, 11)

# %%
df.describe()
# Out:
#        vote_average    vote_count   popularity        budget       revenue  \
# count   9223.000000   9223.000000  9223.000000  9.223000e+03  9.223000e+03
# mean       6.542546   1652.788247    31.635078  2.081719e+07  6.479669e+07
# std        0.907423   2952.562540   114.867339  3.935068e+07  1.596469e+08
# min        1.000000      1.000000     7.411000  0.000000e+00  0.000000e+00
# 25%        6.000000    170.000000    13.591000  0.000000e+00  0.000000e+00
# 50%        6.600000    580.000000    17.619000  2.500000e+06  3.769990e+06
# 75%        7.200000   1726.000000    27.182500  2.500000e+07  5.806524e+07
# max       10.000000  33633.000000  5089.969000  5.793304e+08  2.923706e+09
#
#            runtime
# count  9223.000000
# mean    103.287867
# std      24.410714
# min       2.000000
# 25%      91.000000
# 50%     101.000000
# 75%     115.000000
# max     449.000000

# %%
# kar sutünü ekleme 
df['profit'] = df['revenue'] - df['budget']

# %%
df.head()
# Out:
#                                title release_date  \
# 0                The Pope's Exorcist   2023-04-05
# 1  Ant-Man and the Wasp: Quantumania   2023-02-15
# 2        The Super Mario Bros. Movie   2023-04-05
# 3                            Ghosted   2023-04-18
# 4           Shazam! Fury of the Gods   2023-03-15
#
#                                               genres original_language  \
# 0                  ['Horror', 'Mystery', 'Thriller']           English
# 1         ['Action', 'Adventure', 'Science Fiction']           English
# 2  ['Animation', 'Adventure', 'Family', 'Fantasy'...           English
# 3                    ['Action', 'Comedy', 'Romance']           English
# 4       ['Action', 'Comedy', 'Fantasy', 'Adventure']           English
#
#    vote_average  vote_count  popularity     budget  \
# 0           7.4         619    5089.969   18000000
# 1           6.6        2294    4665.438  200000000
# 2           7.5        1861    3935.550  100000000
# 3           7.2         652    2791.532          0
# 4           6.8        1510    2702.593  125000000
#
#                                 production_companies     revenue  runtime  \
# 0  ['Screen Gems', '2.0 Entertainment', 'Jesus & ...    65675816      103
# 1      ['Marvel Studios', 'Kevin Feige Productions']   464566092      125
# 2  ['Universal Pictures', 'Illumination', 'Ninten...  1121048165       92
# 3                ['Skydance Media', 'Apple Studios']           0      120
# 4  ['New Line Cinema', 'The Safran Company', 'DC ...   133437105      130
#
#        profit
# 0    47675816
# 1   264566092
# 2  1021048165
# 3           0
# 4     8437105

# %%
df.to_csv("movies.csv" ,index = False)

# %%
# Her Kategorinin En İyi 10 Filmi

max_budget = df.sort_values("budget",ascending = False).head(10)
max_revenue = df.sort_values('revenue', ascending=False).head(10)
max_profit = df.sort_values('profit', ascending=False).head(10)
max_loss = df.sort_values('profit', ascending=True).head(10)
max_loss['loss'] = -max_loss['profit']
max_popularity = df.sort_values('popularity', ascending=False).head(10)
max_vc = df.sort_values('vote_count', ascending=False).head(10)
max_va = df.sort_values('vote_average', ascending=False).head(10)

# %%
fig, axs = plt.subplots(4,1,figsize=(10,28))

col_map = plt.get_cmap('tab20')
axs[0].barh(max_budget['title'], max_budget['budget'], color=col_map.colors)
axs[0].set_title('En yüksek bütçeli 10 film')
axs[0].set_xlabel('Budget')
axs[0].set_ylabel('Movies')
for i in range(len(max_budget)):
    axs[0].text(max_budget['budget'].iloc[i], max_budget['title'].iloc[i], max_budget['budget'].iloc[i])

col_map = plt.get_cmap('tab10')
axs[1].barh(max_revenue['title'], max_revenue['revenue'], color=col_map.colors)
axs[1].set_title('En yüksek gelir getiren ilk 10 film')
axs[1].set_xlabel('Revenue')
axs[1].set_ylabel('Movies')
for i in range(len(max_revenue)):
    axs[1].text(max_revenue['revenue'].iloc[i], max_revenue['title'].iloc[i], max_revenue['revenue'].iloc[i])

col_map = plt.get_cmap('tab20c')
axs[2].barh(max_profit['title'], max_profit['profit'], color=col_map.colors)
axs[2].set_title('En çok kazandıran 10 film')
axs[2].set_xlabel('Profit')
axs[2].set_ylabel('Movies')
for i in range(len(max_profit)):
    axs[2].text(max_profit['profit'].iloc[i], max_profit['title'].iloc[i], max_profit['profit'].iloc[i])
    
col_map = plt.get_cmap('tab20')
axs[3].barh(max_loss['title'], max_loss['loss'], color=col_map.colors)
axs[3].set_title('En çok zarar ettiren 10 film')
axs[3].set_xlabel('Loss')
axs[3].set_ylabel('Movies')
for i in range(len(max_loss)):
    axs[3].text(max_loss['loss'].iloc[i], max_loss['title'].iloc[i], max_loss['loss'].iloc[i])

plt.show()

# %%
fig, axs = plt.subplots(3,1,figsize=(10,21))

col_map = plt.get_cmap('tab20')
axs[0].barh(max_popularity['title'], max_popularity['popularity'], color=col_map.colors)
axs[0].set_title('En popüler 10 film')
axs[0].set_xlabel('Popularity')
axs[0].set_ylabel('Movies')
for i in range(len(max_popularity)):
    axs[0].text(max_popularity['popularity'].iloc[i], max_popularity['title'].iloc[i], max_popularity['popularity'].iloc[i])

col_map = plt.get_cmap('tab10')
axs[1].barh(max_vc['title'], max_vc['vote_count'], color=col_map.colors)
axs[1].set_title('En yüksek oyu alan 10 film')
axs[1].set_xlabel('Vote Count')
axs[1].set_ylabel('Movies')
for i in range(len(max_vc)):
    axs[1].text(max_vc['vote_count'].iloc[i], max_vc['title'].iloc[i], max_vc['vote_count'].iloc[i])

col_map = plt.get_cmap('tab20c')
axs[2].barh(max_va['title'], max_va['vote_average'], color=col_map.colors)
axs[2].set_title('En yüksek oy ortalamasına sahip ilk 10 film')
axs[2].set_xlabel('Vote Average')
axs[2].set_ylabel('Movies')
for i in range(len(max_va)):
    axs[2].text(max_va['vote_average'].iloc[i], max_va['title'].iloc[i], max_va['vote_average'].iloc[i])

plt.show()

# %%
df["original_language"].value_counts()
# Out:
# English             6962
# Japanese             648
# Spanish              289
# French               283
# Korean               182
# Italian              143
# cn                   119
# Chinese              108
# German                78
# Russian               65
# Tagalog               35
# Hindi                 33
# Norwegian             31
# Danish                30
# Polish                26
# Portuguese            24
# Thai                  23
# Swedish               23
# Dutch                 22
# Indonesian            16
# Turkish               14
# Tamil                  8
# Telugu                 7
# Finnish                6
# Greek                  4
# Romanian               4
# Ukrainian              4
# Arabic                 3
# Basque                 3
# Hungarian              3
# Persian                3
# Galician               2
# Khmer                  2
# Kannada                2
# Czech                  2
# Malayalam              2
# Serbian                2
# Hebrew                 2
# Catalan                2
# Icelandic              2
# Estonian               1
# Vietnamese             1
# Norwegian Bokmal       1
# Irish                  1
# Macedonian             1
# Dzongkha               1
# Name: original_language, dtype: int64
